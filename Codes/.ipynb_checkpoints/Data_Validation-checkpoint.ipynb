# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Tehran price index DF

# %%
tehran_index = pd.read_excel('../Data/Tehran_Indexes_Price_NoRegime.xlsx').set_index('date')

# %%
tehran_index[tehran_index.columns[0]].plot()
plt.title(tehran_index.columns[0])
plt.grid()

# %% [markdown]
# # Tehran normed returned DF

# %% [markdown]
# We should be careful about using normed returned DF such that it is normed and different from return.

# %%
tehran_df = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')

# %%
col = 20
tehran_df[tehran_df.columns[col]].plot()
plt.title(tehran_df.columns[col])
plt.grid()

# %% [markdown]
# # S&P500 Index DF

# %%
snp500_index = pd.read_excel('../Data/S&P500_Index.xlsx').set_index('Date')[::-1]

# %%
snp500_index[snp500_index.columns[0]].plot()
plt.title(snp500_index.columns[0])
plt.grid()
