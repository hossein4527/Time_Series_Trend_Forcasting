# %%
from ned import Net_moduls
import networkx as nx
import numpy as np

# %%
from nxviz.plots import CircosPlot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %% [markdown]
# ## Tehran Index DF and Tehran DF Normed Return 90 Far - 00 Far

# %%
tehran_index = pd.read_excel('../Data/Tehran_Indexes_Price_NoRegime.xlsx').set_index('date')

# %%
tehran_df_reg = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')

# %% [markdown]
# ## Tehran DF Normed Return 90 Far - 98 Dey

# %%
tehran_df = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')
tehran_df = tehran_df[tehran_df.columns[:-12]].iloc[:-300]

# %% [markdown]
# ## Tehran DF Normed Return 90 Far - 00 Far

# %%
tehran_df_completeDates = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')
tehran_df_completeDates = tehran_df_completeDates[tehran_df_completeDates.columns[:-12]]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 00 Far

# %%
tehran_df_TwoReg_Ox_1 = tehran_df_reg[tehran_df_reg['Ox_2']==0]
tehran_df_TwoReg_Ox_2 = tehran_df_reg[tehran_df_reg['Ox_2']==1]
tehran_df_TwoReg_Ox_1 = tehran_df_TwoReg_Ox_1[tehran_df_TwoReg_Ox_1.columns[:-12]]
tehran_df_TwoReg_Ox_2 = tehran_df_TwoReg_Ox_2[tehran_df_TwoReg_Ox_2.columns[:-12]]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_TwoReg_Ox_1_98 = tehran_df[tehran_df_reg['Ox_2']==0]
tehran_df_TwoReg_Ox_2_98 = tehran_df[tehran_df_reg['Ox_2']==1]
# Out:
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/2195039282.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_TwoReg_Ox_1_98 = tehran_df[tehran_df_reg['Ox_2']==0]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/2195039282.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_TwoReg_Ox_2_98 = tehran_df[tehran_df_reg['Ox_2']==1]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 00 Far / Same Length

# %%
max_length_TwoReg_Ox_2 = min(len(tehran_df_TwoReg_Ox_1), len(tehran_df_TwoReg_Ox_2))
tehran_df_TwoReg_Ox_1_same_length = tehran_df_TwoReg_Ox_1[-max_length_TwoReg_Ox_2:]
tehran_df_TwoReg_Ox_2_same_length = tehran_df_TwoReg_Ox_2[-max_length_TwoReg_Ox_2:]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_TwoReg_Ox_2_98 = min(len(tehran_df_TwoReg_Ox_1_98), len(tehran_df_TwoReg_Ox_2_98))
tehran_df_TwoReg_Ox_1_same_length_98 = tehran_df_TwoReg_Ox_1_98[-max_length_TwoReg_Ox_2_98:]
tehran_df_TwoReg_Ox_2_same_length_98 = tehran_df_TwoReg_Ox_2_98[-max_length_TwoReg_Ox_2_98:]

# %% [markdown]
# ## Tehran Ox 3 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_ThreeReg_Ox_1_98 = tehran_df[tehran_df_reg['Ox_3']==0]
tehran_df_ThreeReg_Ox_2_98 = tehran_df[tehran_df_reg['Ox_3']==1]
tehran_df_ThreeReg_Ox_3_98 = tehran_df[tehran_df_reg['Ox_3']==2]
# Out:
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/3966413187.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_ThreeReg_Ox_1_98 = tehran_df[tehran_df_reg['Ox_3']==0]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/3966413187.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_ThreeReg_Ox_2_98 = tehran_df[tehran_df_reg['Ox_3']==1]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/3966413187.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_ThreeReg_Ox_3_98 = tehran_df[tehran_df_reg['Ox_3']==2]

# %% [markdown]
# ## Tehran Ox 3 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_ThreeReg_Ox_90_98 = min(len(tehran_df_ThreeReg_Ox_1_98), len(tehran_df_ThreeReg_Ox_2_98),len(tehran_df_ThreeReg_Ox_3_98))
tehran_df_ThreeReg_Ox_1_same_length_98 = tehran_df_ThreeReg_Ox_1_98[-max_length_ThreeReg_Ox_90_98:]
tehran_df_ThreeReg_Ox_2_same_length_98 = tehran_df_ThreeReg_Ox_2_98[-max_length_ThreeReg_Ox_90_98:]
tehran_df_ThreeReg_Ox_3_same_length_98 = tehran_df_ThreeReg_Ox_3_98[-max_length_ThreeReg_Ox_90_98:]

# %% [markdown]
# ## Tehran pn 3 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_ThreeReg_pn_1_98 = tehran_df[tehran_df_reg['3_PN']==1]
tehran_df_ThreeReg_pn_2_98 = tehran_df[tehran_df_reg['3_PN']==2]
tehran_df_ThreeReg_pn_3_98 = tehran_df[tehran_df_reg['3_PN']==3]
# Out:
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1219616497.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_ThreeReg_pn_1_98 = tehran_df[tehran_df_reg['3_PN']==1]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1219616497.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_ThreeReg_pn_2_98 = tehran_df[tehran_df_reg['3_PN']==2]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1219616497.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_ThreeReg_pn_3_98 = tehran_df[tehran_df_reg['3_PN']==3]

# %% [markdown]
# ## Tehran pn 3 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_ThreeReg_pn_90_98 = min(len(tehran_df_ThreeReg_pn_1_98), len(tehran_df_ThreeReg_pn_2_98),len(tehran_df_ThreeReg_pn_3_98))
tehran_df_ThreeReg_pn_1_same_length_98 = tehran_df_ThreeReg_pn_1_98[-max_length_ThreeReg_pn_90_98:]
tehran_df_ThreeReg_pn_2_same_length_98 = tehran_df_ThreeReg_pn_2_98[-max_length_ThreeReg_pn_90_98:]
tehran_df_ThreeReg_pn_3_same_length_98 = tehran_df_ThreeReg_pn_3_98[-max_length_ThreeReg_pn_90_98:]

# %% [markdown]
# ## Tehran pn 6 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_SixReg_pn_1_98 = tehran_df[tehran_df_reg['6_(2pn)']==1]
tehran_df_SixReg_pn_2_98 = tehran_df[tehran_df_reg['6_(2pn)']==2]
tehran_df_SixReg_pn_3_98 = tehran_df[tehran_df_reg['6_(2pn)']==3]
tehran_df_SixReg_pn_4_98 = tehran_df[tehran_df_reg['6_(2pn)']==4]
tehran_df_SixReg_pn_5_98 = tehran_df[tehran_df_reg['6_(2pn)']==5]
tehran_df_SixReg_pn_6_98 = tehran_df[tehran_df_reg['6_(2pn)']==6]
# Out:
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/642849216.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_SixReg_pn_1_98 = tehran_df[tehran_df_reg['6_(2pn)']==1]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/642849216.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_SixReg_pn_2_98 = tehran_df[tehran_df_reg['6_(2pn)']==2]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/642849216.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_SixReg_pn_3_98 = tehran_df[tehran_df_reg['6_(2pn)']==3]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/642849216.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_SixReg_pn_4_98 = tehran_df[tehran_df_reg['6_(2pn)']==4]
# ...

# %% [markdown]
# ## Tehran pn 6 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_SixReg_pn_90_98 = min(len(tehran_df_SixReg_pn_1_98), len(tehran_df_SixReg_pn_2_98),len(tehran_df_SixReg_pn_3_98),\
                                  len(tehran_df_SixReg_pn_4_98), len(tehran_df_SixReg_pn_5_98),len(tehran_df_SixReg_pn_6_98))
tehran_df_SixReg_pn_1_same_length_98 = tehran_df_SixReg_pn_1_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_2_same_length_98 = tehran_df_SixReg_pn_2_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_3_same_length_98 = tehran_df_SixReg_pn_3_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_4_same_length_98 = tehran_df_SixReg_pn_4_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_5_same_length_98 = tehran_df_SixReg_pn_5_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_6_same_length_98 = tehran_df_SixReg_pn_6_98[-max_length_SixReg_pn_90_98:]

# %% [markdown]
# ## Tehran pn 9 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_NineReg_pn_1_98 = tehran_df[tehran_df_reg['9_(3pn)']==1]
tehran_df_NineReg_pn_2_98 = tehran_df[tehran_df_reg['9_(3pn)']==2]
tehran_df_NineReg_pn_3_98 = tehran_df[tehran_df_reg['9_(3pn)']==3]
tehran_df_NineReg_pn_4_98 = tehran_df[tehran_df_reg['9_(3pn)']==4]
tehran_df_NineReg_pn_5_98 = tehran_df[tehran_df_reg['9_(3pn)']==5]
tehran_df_NineReg_pn_6_98 = tehran_df[tehran_df_reg['9_(3pn)']==6]
tehran_df_NineReg_pn_7_98 = tehran_df[tehran_df_reg['9_(3pn)']==7]
tehran_df_NineReg_pn_8_98 = tehran_df[tehran_df_reg['9_(3pn)']==8]
tehran_df_NineReg_pn_9_98 = tehran_df[tehran_df_reg['9_(3pn)']==9]
# Out:
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1896610776.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_NineReg_pn_1_98 = tehran_df[tehran_df_reg['9_(3pn)']==1]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1896610776.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_NineReg_pn_2_98 = tehran_df[tehran_df_reg['9_(3pn)']==2]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1896610776.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_NineReg_pn_3_98 = tehran_df[tehran_df_reg['9_(3pn)']==3]
# /var/folders/mj/xw3m0dws3yq8j2md9n8j3g940000gn/T/ipykernel_1380/1896610776.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tehran_df_NineReg_pn_4_98 = tehran_df[tehran_df_reg['9_(3pn)']==4]
# ...

# %% [markdown]
# ## Tehran pn 9 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
(len(tehran_df_NineReg_pn_1_98), len(tehran_df_NineReg_pn_2_98),len(tehran_df_NineReg_pn_3_98),\
                                  len(tehran_df_NineReg_pn_4_98), len(tehran_df_NineReg_pn_5_98),len(tehran_df_NineReg_pn_6_98)\
                                 ,len(tehran_df_NineReg_pn_7_98),len(tehran_df_NineReg_pn_8_98),len(tehran_df_NineReg_pn_9_98))
# Out:
# (780, 67, 400, 89, 20, 151, 226, 36, 329)

# %%
max_length_NineReg_pn_90_98 = min(len(tehran_df_NineReg_pn_1_98), len(tehran_df_NineReg_pn_2_98),len(tehran_df_NineReg_pn_3_98),\
                                  len(tehran_df_NineReg_pn_4_98), len(tehran_df_NineReg_pn_5_98),len(tehran_df_NineReg_pn_6_98)\
                                 ,len(tehran_df_NineReg_pn_7_98),len(tehran_df_NineReg_pn_8_98),len(tehran_df_NineReg_pn_9_98))
tehran_df_NineReg_pn_1_same_length_98 = tehran_df_NineReg_pn_1_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_2_same_length_98 = tehran_df_NineReg_pn_2_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_3_same_length_98 = tehran_df_NineReg_pn_3_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_4_same_length_98 = tehran_df_NineReg_pn_4_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_5_same_length_98 = tehran_df_NineReg_pn_5_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_6_same_length_98 = tehran_df_NineReg_pn_6_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_7_same_length_98 = tehran_df_NineReg_pn_7_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_8_same_length_98 = tehran_df_NineReg_pn_8_98[-max_length_NineReg_pn_90_98:]
tehran_df_NineReg_pn_9_same_length_98 = tehran_df_NineReg_pn_9_98[-max_length_NineReg_pn_90_98:]

# %% [markdown]
# # 65) Tehran 9 pn Regime Pearson (Based on Median Threshold) Period of 90 Far - 98 Dey

# %%
nm = Net_moduls()

# %%
thr65_1 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_1_same_length_98)
thr65_2 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_2_same_length_98)
thr65_3 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_3_same_length_98)
thr65_4 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_4_same_length_98)
thr65_5 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_5_same_length_98)
thr65_6 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_6_same_length_98)
thr65_7 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_4_same_length_98)
thr65_8 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_5_same_length_98)
thr65_9 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_6_same_length_98)

thr65 = min(thr65_1, thr65_2, thr65_3, thr65_4, thr65_5, thr65_6, thr65_7, thr65_8, thr65_9)

# %%
nm = Net_moduls()
pearson_network_NineReg_pn_1_98 = nm.construct_network(tehran_df_NineReg_pn_1_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_1_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.776812              804            0.818171
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.776812                    0.005072
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.826374                      1.223188

# %%
pearson_network_NineReg_pn_2_98 = nm.construct_network(tehran_df_NineReg_pn_2_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_2_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.792271              820            0.827513
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.792271                    0.004721
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.836543                      1.207729

# %%
pearson_network_NineReg_pn_3_98 = nm.construct_network(tehran_df_NineReg_pn_3_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_3_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.773913              801            0.827773
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.773913                    0.005138
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.825939                      1.226087

# %%
pearson_network_NineReg_pn_4_98 = nm.construct_network(tehran_df_NineReg_pn_4_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_4_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.807071              799            0.845347
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.807071                    0.004487
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.847384                      1.192929

# %%
pearson_network_NineReg_pn_5_98 = nm.construct_network(tehran_df_NineReg_pn_5_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_5_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.712303              770            0.758665
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.712303                    0.006393
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.784411                      1.287697

# %%
pearson_network_NineReg_pn_6_98 = nm.construct_network(tehran_df_NineReg_pn_6_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_6_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.756522              783            0.801239
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.756522                    0.005534
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                   0.81343                      1.243478

# %%
pearson_network_NineReg_pn_7_98 = nm.construct_network(tehran_df_NineReg_pn_7_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_7_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.790909              783            0.822065
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.790909                    0.004863
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.834513                      1.209091

# %%
pearson_network_NineReg_pn_8_98 = nm.construct_network(tehran_df_NineReg_pn_8_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_8_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.774283              837            0.795843
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.774283                    0.005016
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.821564                      1.225717

# %%
pearson_network_NineReg_pn_9_98 = nm.construct_network(tehran_df_NineReg_pn_9_same_length_98, method='pearson', threshold=thr65)

# %%
nm.get_network_features(pearson_network_NineReg_pn_9_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.757576              750            0.768677
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.757576                    0.005638
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.808775                      1.242424

# %% [markdown]
# # 66) Tehran 6 pn Regime Pearson (Based on Median Threshold) Period of 90 Far - 00 Far

# %%
# thr21_1 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_1_same_length_98)
# thr21_2 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_2_same_length_98)
# thr21_3 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_3_same_length_98)

# thr21 = min(thr8_1, thr8_2)

# %%
# nm = Net_moduls()
# pearson_network_TwoReg_pn_1 = nm.construct_network(tehran_df_TwoReg_pn_1_same_length, method='pearson', threshold=thr8)

# %%
# nm.get_network_features(pearson_network_TwoReg_pn_1)

# %%
# circos = nm.plot_circos_network(pearson_network_TwoReg_pn_1)
# circos.draw()

# %%
# pearson_network_TwoReg_pn_2 = nm.construct_network(tehran_df_TwoReg_pn_2_same_length, method='pearson', threshold=thr8)

# %%
# nm.get_network_features(pearson_network_TwoReg_pn_2)

# %%
# circos = nm.plot_circos_network(pearson_network_TwoReg_pn_2)
# circos.draw()

# %% [markdown]
# # 67) Tehran 9 pn Regime Pearson (Based on Median Threshold) Period of 90 Far - 98 Dey/ Last 100 Records

# %%
thr67_1 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_1_same_length_98[-100:])
thr67_2 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_2_same_length_98[-100:])
thr67_3 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_3_same_length_98[-100:])
thr67_4 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_4_same_length_98[-100:])
thr67_5 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_5_same_length_98[-100:])
thr67_6 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_6_same_length_98[-100:])
thr67_7 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_4_same_length_98[-100:])
thr67_8 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_5_same_length_98[-100:])
thr67_9 = nm.find_median_pearson_threshold(tehran_df_NineReg_pn_6_same_length_98[-100:])

thr67 = min(thr67_1, thr67_2, thr67_3, thr67_4, thr67_5, thr67_6, thr67_7, thr67_8, thr67_9)

# %%
pearson_network_NineReg_pn_1_98_last100 = nm.construct_network(tehran_df_NineReg_pn_1_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_1_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.776812              804            0.818171
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.776812                    0.005072
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.826374                      1.223188

# %%
pearson_network_NineReg_pn_2_98_last100 = nm.construct_network(tehran_df_NineReg_pn_2_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_2_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.792271              820            0.827513
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.792271                    0.004721
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.836543                      1.207729

# %%
pearson_network_NineReg_pn_3_98_last100 = nm.construct_network(tehran_df_NineReg_pn_3_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_3_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.773913              801            0.827773
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.773913                    0.005138
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.825939                      1.226087

# %%
pearson_network_NineReg_pn_4_98_last100 = nm.construct_network(tehran_df_NineReg_pn_4_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_4_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.807071              799            0.845347
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.807071                    0.004487
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.847384                      1.192929

# %%
pearson_network_NineReg_pn_5_98_last100 = nm.construct_network(tehran_df_NineReg_pn_5_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_5_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.712303              770            0.758665
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.712303                    0.006393
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.784411                      1.287697

# %%
pearson_network_NineReg_pn_6_98_last100 = nm.construct_network(tehran_df_NineReg_pn_6_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_6_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.756522              783            0.801239
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.756522                    0.005534
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                   0.81343                      1.243478

# %%
pearson_network_NineReg_pn_7_98_last100 = nm.construct_network(tehran_df_NineReg_pn_7_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_7_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.790909              783            0.822065
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.790909                    0.004863
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.834513                      1.209091

# %%
pearson_network_NineReg_pn_8_98_last100 = nm.construct_network(tehran_df_NineReg_pn_8_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_8_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.774283              837            0.795843
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.774283                    0.005016
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.821564                      1.225717

# %%
pearson_network_NineReg_pn_9_98_last100 = nm.construct_network(tehran_df_NineReg_pn_9_same_length_98[-100:], method='pearson', threshold=thr67)

# %%
nm.get_network_features(pearson_network_NineReg_pn_9_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.757576              750            0.768677
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.757576                    0.005638
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.808775                      1.242424

# %% [markdown]
# # 68) Tehran 9 pn Regime Pearson (Based on Median Threshold) Period of 90 Far - 98 Dey/ 50 windows of 100 Records

# %%
# nm = Net_moduls()
# pearson_network_NineReg_pn_1_98_averged = nm.get_network_features_averaged_median(tehran_df, regimes_column = tehran_df_reg['9_(3pn)'], method='pearson', edges_threshold=200, target_window=100, target_length=2)

# %%
# pearson_network_NineReg_pn_1_98_averged

# %% [markdown]
# # 69) Tehran 9 pn Regime Pearson (Based on Median Threshold) Period of 90 Far - 00 Far/ 50 windows of 100 Records

# %%
# nm = Net_moduls()
# pearson_network_SixReg_pn_90_00_averged = nm.get_network_features_averaged_median(tehran_df_completeDates, regimes_column= tehran_df_reg['6_(2pn)'],method='pearson',edges_threshold=200, target_window=100, target_length=50)

# %%
# pearson_network_SixReg_pn_90_00_averged

# %% [markdown]
# # 70) Tehran 9 pn Regime Entropy (Based on Median Threshold) Period of 90 Far - 98 Dey

# %%
nm = Net_moduls()

# %%
thr70_1 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_1_same_length_98)
thr70_2 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_2_same_length_98)
thr70_3 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_3_same_length_98)
thr70_4 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_4_same_length_98)
thr70_5 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_5_same_length_98)
thr70_6 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_6_same_length_98)
thr70_7 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_4_same_length_98)
thr70_8 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_5_same_length_98)
thr70_9 = nm.find_median_entropy_threshold(tehran_df_NineReg_pn_6_same_length_98)

thr70 = min(thr70_1, thr70_2, thr70_3, thr70_4, thr70_5, thr70_6, thr70_7, thr70_8, thr70_9)

# %%
nm = Net_moduls()
entropy_network_NineReg_pn_1_98 = nm.construct_network(tehran_df_NineReg_pn_1_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_1_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2    0.67343              697            0.695868
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0                0.67343                    0.007422
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                   0.76652                       1.32657

# %%
entropy_network_NineReg_pn_2_98 = nm.construct_network(tehran_df_NineReg_pn_2_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_2_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.531401              550            0.649292
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.531401                     0.01065
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.704012                      1.468599

# %%
entropy_network_NineReg_pn_3_98 = nm.construct_network(tehran_df_NineReg_pn_3_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_3_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.657971              681             0.65967
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.657971                    0.007773
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.759769                      1.342029

# %%
entropy_network_NineReg_pn_4_98 = nm.construct_network(tehran_df_NineReg_pn_4_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_4_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.772727              765            0.754167
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.772727                    0.005285
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.819264                      1.227273

# %%
entropy_network_NineReg_pn_5_98 = nm.construct_network(tehran_df_NineReg_pn_5_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_5_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.715079              773            0.717392
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.715079                    0.006332
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.788548                      1.284921

# %%
entropy_network_NineReg_pn_6_98 = nm.construct_network(tehran_df_NineReg_pn_6_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_6_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.752657              779            0.777256
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.752657                    0.005621
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.812583                      1.247343

# %%
entropy_network_NineReg_pn_7_98 = nm.construct_network(tehran_df_NineReg_pn_7_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_7_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.647475              641            0.700068
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.647475                    0.008198
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.754778                      1.352525

# %%
entropy_network_NineReg_pn_8_98 = nm.construct_network(tehran_df_NineReg_pn_8_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_8_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       1         2   0.719704              778            0.734252
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.719704                    0.006229
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.790544                      1.280296

# %%
entropy_network_NineReg_pn_9_98 = nm.construct_network(tehran_df_NineReg_pn_9_same_length_98, method='entropy', threshold=thr70)

# %%
nm.get_network_features(entropy_network_NineReg_pn_9_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.810101              802            0.798746
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.810101                    0.004416
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                   0.84447                      1.189899

# %% [markdown]
# # 71) Tehran 9 pn Regime Entropy (Based on Median Threshold) Period of 90 Far - 00 Far

# %%
# thr21_1 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_1_same_length_98)
# thr21_2 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_2_same_length_98)
# thr21_3 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_3_same_length_98)

# thr21 = min(thr8_1, thr8_2)

# %%
# nm = Net_moduls()
# pearson_network_TwoReg_pn_1 = nm.construct_network(tehran_df_TwoReg_pn_1_same_length, method='pearson', threshold=thr8)

# %%
# nm.get_network_features(pearson_network_TwoReg_pn_1)

# %%
# circos = nm.plot_circos_network(pearson_network_TwoReg_pn_1)
# circos.draw()

# %%
# pearson_network_TwoReg_pn_2 = nm.construct_network(tehran_df_TwoReg_pn_2_same_length, method='pearson', threshold=thr8)

# %%
# nm.get_network_features(pearson_network_TwoReg_pn_2)

# %%
# circos = nm.plot_circos_network(pearson_network_TwoReg_pn_2)
# circos.draw()

# %% [markdown]
# # 72) Tehran 9 pn Regime Entropy (Based on Median Threshold) Period of 90 Far - 98 Dey/ Last 100 Records

# %%
# thr57_1 = nm.find_median_entropy_threshold(tehran_df_SixReg_pn_1_same_length_98[-100:])
# thr57_2 = nm.find_median_entropy_threshold(tehran_df_SixReg_pn_2_same_length_98[-100:])
# thr57_3 = nm.find_median_entropy_threshold(tehran_df_SixReg_pn_3_same_length_98[-100:])
# thr57_4 = nm.find_median_entropy_threshold(tehran_df_SixReg_pn_4_same_length_98[-100:])
# thr57_5 = nm.find_median_entropy_threshold(tehran_df_SixReg_pn_5_same_length_98[-100:])
# thr57_6 = nm.find_median_entropy_threshold(tehran_df_SixReg_pn_6_same_length_98[-100:])

# thr57 = min(thr57_1, thr57_2, thr57_3, thr57_4, thr57_5, thr57_6)

# %%
# entropy_network_SixReg_pn_1_98_last100 = nm.construct_network(tehran_df_SixReg_pn_1_same_length_98[-100:], method='entropy', threshold=thr57)

# %%
# nm.get_network_features(entropy_network_SixReg_pn_1_98_last100)

# %%
# entropy_network_SixReg_pn_2_98_last100 = nm.construct_network(tehran_df_SixReg_pn_2_same_length_98[-100:], method='entropy', threshold=thr57)

# %%
# nm.get_network_features(entropy_network_SixReg_pn_2_98_last100)

# %%
# entropy_network_SixReg_pn_3_98_last100 = nm.construct_network(tehran_df_SixReg_pn_3_same_length_98[-100:], method='entropy', threshold=thr57)

# %%
# nm.get_network_features(entropy_network_SixReg_pn_3_98_last100)

# %%
# entropy_network_SixReg_pn_4_98_last100 = nm.construct_network(tehran_df_SixReg_pn_4_same_length_98[-100:], method='entropy', threshold=thr57)

# %%
# nm.get_network_features(entropy_network_SixReg_pn_4_98_last100)

# %%
# entropy_network_SixReg_pn_5_98_last100 = nm.construct_network(tehran_df_SixReg_pn_5_same_length_98[-100:], method='entropy', threshold=thr57)

# %%
# nm.get_network_features(entropy_network_SixReg_pn_5_98_last100)

# %%
# entropy_network_SixReg_pn_6_98_last100 = nm.construct_network(tehran_df_SixReg_pn_6_same_length_98[-100:], method='entropy', threshold=thr57)

# %%
# nm.get_network_features(entropy_network_SixReg_pn_6_98_last100)

# %% [markdown]
# # 73) Tehran 9 pn Regime Entropy (Based on Median Threshold) Period of 90 Far - 98 Dey/ 50 windows of 100 Records

# %%
# nm = Net_moduls()
# entropy_network_SixReg_pn_1_98_averged = nm.get_network_features_averaged_median(tehran_df, regimes_column = tehran_df_reg['6_(2pn)'],method='entropy',edges_threshold=200, target_window=50, target_length=10)

# %%
# entropy_network_SixReg_pn_1_98_averged

# %% [markdown]
# # 74) Tehran 9 pn Regime Entropy (Based on Median Threshold) Period of 90 Far - 00 Far/ 50 windows of 100 Records

# %%
# nm = Net_moduls()
# entropy_network_SixReg_pn_90_00_averged = nm.get_network_features_averaged_median(tehran_df_completeDates, regimes_column= tehran_df_reg['6_(2pn)'],method='entropy',edges_threshold=200, target_window=100, target_length=50)

# %%
# entropy_network_SixReg_pn_90_00_averged

# %% [markdown]
# # 75) Tehran 9 pn Regime Crossed (Based on Median Threshold) Period of 90 Far - 98 Dey

# %%
nm = Net_moduls()

# %%
thr45_1 = nm.find_median_crossed_100_threshold(tehran_df_SixReg_pn_1_same_length_98)
thr45_2 = nm.find_median_crossed_100_threshold(tehran_df_SixReg_pn_2_same_length_98)
thr45_3 = nm.find_median_crossed_100_threshold(tehran_df_SixReg_pn_3_same_length_98)
thr45_1 = nm.find_median_crossed_100_threshold(tehran_df_SixReg_pn_1_same_length_98)
thr45_2 = nm.find_median_crossed_100_threshold(tehran_df_SixReg_pn_2_same_length_98)
thr45_3 = nm.find_median_crossed_100_threshold(tehran_df_SixReg_pn_3_same_length_98)

thr45 = min(thr45_1, thr45_2, thr45_3)

# %%
crossed_network_SixReg_pn_1_98 = nm.construct_network(tehran_df_SixReg_pn_1_same_length_98, method='crossed_100', threshold=thr45)

# %%
nm.get_network_features(crossed_network_SixReg_pn_1_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.274396              284            0.440188
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.274396                    0.016491
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                   0.58922                      1.725604

# %%
circos = nm.plot_circos_network(crossed_network_SixReg_pn_1_98)
circos.draw()

# %%
crossed_network_SixReg_pn_2_98 = nm.construct_network(tehran_df_SixReg_pn_2_same_length_98, method='crossed_100', threshold=thr45)

# %%
nm.get_network_features(crossed_network_SixReg_pn_2_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         3    0.36715              380            0.428634
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0                0.36715                    0.014427
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.617081                      1.634783

# %%
circos = nm.plot_circos_network(crossed_network_SixReg_pn_2_98)
circos.draw()

# %%
crossed_network_SixReg_pn_3_98 = nm.construct_network(tehran_df_SixReg_pn_3_same_length_98, method='crossed_100', threshold=thr45)

# %%
nm.get_network_features(crossed_network_SixReg_pn_3_98)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         3   0.360386              373            0.495744
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.360386                    0.014559
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.617053                       1.64058

# %%
circos = nm.plot_circos_network(crossed_network_SixReg_pn_3_98)
circos.draw()

# %% [markdown]
# # 76) Tehran 6 pn Regime Crossed (Based on Median Threshold) Period of 90 Far - 00 Far

# %%
# thr21_1 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_1_same_length_98)
# thr21_2 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_2_same_length_98)
# thr21_3 = nm.find_median_pearson_threshold(tehran_df_SixReg_pn_3_same_length_98)

# thr21 = min(thr8_1, thr8_2)

# %%
# nm = Net_moduls()
# pearson_network_TwoReg_pn_1 = nm.construct_network(tehran_df_TwoReg_pn_1_same_length, method='pearson', threshold=thr8)

# %%
# nm.get_network_features(pearson_network_TwoReg_pn_1)

# %%
# circos = nm.plot_circos_network(pearson_network_TwoReg_pn_1)
# circos.draw()

# %%
# pearson_network_TwoReg_pn_2 = nm.construct_network(tehran_df_TwoReg_pn_2_same_length, method='pearson', threshold=thr8)

# %%
# nm.get_network_features(pearson_network_TwoReg_pn_2)

# %%
# circos = nm.plot_circos_network(pearson_network_TwoReg_pn_2)
# circos.draw()

# %% [markdown]
# # 77) Tehran 6 pn Regime Crossed (Based on Median Threshold) Period of 90 Far - 98 Dey/ Last 100 Records

# %%
thr77_1 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_1_same_length_98[-100:])
thr77_2 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_2_same_length_98[-100:])
thr77_3 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_3_same_length_98[-100:])
thr77_4 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_4_same_length_98[-100:])
thr77_5 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_5_same_length_98[-100:])
thr77_6 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_6_same_length_98[-100:])
thr77_7 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_7_same_length_98[-100:])
thr77_8 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_8_same_length_98[-100:])
thr77_9 = nm.find_median_crossed_100_threshold(tehran_df_NineReg_pn_9_same_length_98[-100:])

thr77 = min(thr77_1, thr77_2, thr77_3, thr77_4, thr77_5, thr77_6, thr77_7, thr77_8, thr77_9 )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)

# %%
crossed_network_NineReg_pn_1_98_last100 = nm.construct_network(tehran_df_SixReg_pn_1_same_length_98[-100:], method='crossed_100', threshold=thr77)

# %%
nm.get_network_features(crossed_network_NineReg_pn_1_98_last100)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0     NaN       NaN          0                0                 NaN
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0                    NaN                         NaN
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                       NaN                           NaN

# %%
crossed_network_SixReg_pn_2_98_last100 = nm.construct_network(tehran_df_SixReg_pn_2_same_length_98[-100:], method='crossed_100', threshold=thr47)

# %%
nm.get_network_features(crossed_network_SixReg_pn_2_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         3   0.377778              391            0.452958
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.377778                    0.014185
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.620629                      1.624155

# %%
crossed_network_SixReg_pn_3_98_last100 = nm.construct_network(tehran_df_SixReg_pn_3_same_length_98[-100:], method='crossed_100', threshold=thr47)

# %%
nm.get_network_features(crossed_network_SixReg_pn_3_98_last100)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         3   0.350725              363            0.470256
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.350725                      0.0148
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.613841                      1.651208

# %% [markdown]
# # 78) Tehran 6 pn Regime Crossed (Based on Median Threshold) Period of 90 Far - 98 Dey/ 50 windows of 100 Records

# %%
# nm = Net_moduls()
# crossed_network_SixReg_pn_1_98_averged = nm.get_network_features_averaged_median(tehran_df, regimes_column = tehran_df_reg['6_(2pn)'],method='crossed_100',edges_threshold=200, target_window=100, target_length=20)

# %%
# crossed_network_SixReg_pn_1_98_averged

# %% [markdown]
# # 79) Tehran 6 pn Regime Crossed (Based on Median Threshold) Period of 90 Far - 00 Far/ 50 windows of 100 Records

# %%
# nm = Net_moduls()
# crossed_network_SixReg_pn_90_00_averged = nm.get_network_features_averaged_median(tehran_df_completeDates, regimes_column= tehran_df_reg['6_(2pn)'],method='crossed_100',edges_threshold=200, target_window=100, target_length=50)

# %%
# crossed_network_SixReg_pn_90_00_averged
