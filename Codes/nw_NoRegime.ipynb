# %%
from ned import Net_moduls
import networkx as nx
import numpy as np

# %%
from nxviz.plots import CircosPlot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %% [markdown]
# ## Tehran Index DF and Tehran DF Normed Return 90 Far - 00 Far

# %%
tehran_index = pd.read_excel('../Data/Tehran_Indexes_Price_NoRegime.xlsx').set_index('date')

# %%
tehran_df_reg = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')

# %%
tehran_index_99 = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed_newox.xlsx').set_index('date')

# %% [markdown]
# ## Tehran DF Normed Return 90 Far - 98 Dey

# %%
tehran_df = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')
tehran_df = tehran_df[tehran_df.columns[:-12]].iloc[:-300]

# %% [markdown]
# ## Tehran DF Normed Return 90 Far - 00 Far

# %%
tehran_df_completeDates = pd.read_excel('../Data/Tehran_Indexes_NormedReturned_Regimed.xlsx').set_index('date')
tehran_df_completeDates = tehran_df_completeDates[tehran_df_completeDates.columns[:-12]]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 00 Far

# %%
tehran_df_TwoReg_Ox_1 = tehran_df_reg[tehran_df_reg['Ox_2']==0]
tehran_df_TwoReg_Ox_2 = tehran_df_reg[tehran_df_reg['Ox_2']==1]
tehran_df_TwoReg_Ox_1 = tehran_df_TwoReg_Ox_1[tehran_df_TwoReg_Ox_1.columns[:-12]]
tehran_df_TwoReg_Ox_2 = tehran_df_TwoReg_Ox_2[tehran_df_TwoReg_Ox_2.columns[:-12]]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_TwoReg_Ox_1_98 = tehran_df[tehran_df_reg.iloc[:-300]['Ox_2']==0]
tehran_df_TwoReg_Ox_2_98 = tehran_df[tehran_df_reg.iloc[:-300]['Ox_2']==1]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 00 Far / Same Length

# %%
max_length_TwoReg_Ox_2 = min(len(tehran_df_TwoReg_Ox_1), len(tehran_df_TwoReg_Ox_2))
tehran_df_TwoReg_Ox_1_same_length = tehran_df_TwoReg_Ox_1[-max_length_TwoReg_Ox_2:]
tehran_df_TwoReg_Ox_2_same_length = tehran_df_TwoReg_Ox_2[-max_length_TwoReg_Ox_2:]

# %% [markdown]
# ## Tehran Ox 2 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_TwoReg_Ox_2_98 = min(len(tehran_df_TwoReg_Ox_1_98), len(tehran_df_TwoReg_Ox_2_98))
tehran_df_TwoReg_Ox_1_same_length_98 = tehran_df_TwoReg_Ox_1_98[-max_length_TwoReg_Ox_2_98:]
tehran_df_TwoReg_Ox_2_same_length_98 = tehran_df_TwoReg_Ox_2_98[-max_length_TwoReg_Ox_2_98:]

# %% [markdown]
# ## Tehran Ox 2 1399 Regimed DF Normed Return 99 - 1400

# %%
tehran_df_TwoReg_Ox_99_1 = tehran_df_reg[tehran_index_99['ox-2-1year']==0]
tehran_df_TwoReg_Ox_99_2 = tehran_df_reg[tehran_index_99['ox-2-1year']==1]
tehran_df_TwoReg_Ox_99_1 = tehran_df_TwoReg_Ox_99_1[tehran_df_TwoReg_Ox_99_1.columns[:-12]]
tehran_df_TwoReg_Ox_99_2 = tehran_df_TwoReg_Ox_99_2[tehran_df_TwoReg_Ox_99_2.columns[:-12]]

# %%
max_length_TwoReg_Ox_99_2 = min(len(tehran_df_TwoReg_Ox_99_1), len(tehran_df_TwoReg_Ox_99_2))
tehran_df_TwoReg_Ox_99_1_same_length = tehran_df_TwoReg_Ox_99_1[-max_length_TwoReg_Ox_99_2:]
tehran_df_TwoReg_Ox_99_2_same_length = tehran_df_TwoReg_Ox_99_2[-max_length_TwoReg_Ox_99_2:]

# %% [markdown]
# ## Tehran Ox 3 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_ThreeReg_Ox_1_98 = tehran_df[tehran_df_reg.iloc[:-300]['Ox_3']==0]
tehran_df_ThreeReg_Ox_2_98 = tehran_df[tehran_df_reg.iloc[:-300]['Ox_3']==1]
tehran_df_ThreeReg_Ox_3_98 = tehran_df[tehran_df_reg.iloc[:-300]['Ox_3']==2]

# %% [markdown]
# ## Tehran Ox 3 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_ThreeReg_Ox_90_98 = min(len(tehran_df_ThreeReg_Ox_1_98), len(tehran_df_ThreeReg_Ox_2_98),len(tehran_df_ThreeReg_Ox_3_98))
tehran_df_ThreeReg_Ox_1_same_length_98 = tehran_df_ThreeReg_Ox_1_98[-max_length_ThreeReg_Ox_90_98:]
tehran_df_ThreeReg_Ox_2_same_length_98 = tehran_df_ThreeReg_Ox_2_98[-max_length_ThreeReg_Ox_90_98:]
tehran_df_ThreeReg_Ox_3_same_length_98 = tehran_df_ThreeReg_Ox_3_98[-max_length_ThreeReg_Ox_90_98:]

# %% [markdown]
# ## Tehran pn 3 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_ThreeReg_pn_1_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==1]
tehran_df_ThreeReg_pn_2_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==2]
tehran_df_ThreeReg_pn_3_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==3]

# %% [markdown]
# ## Tehran pn 3 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_ThreeReg_pn_90_98 = min(len(tehran_df_ThreeReg_pn_1_98), len(tehran_df_ThreeReg_pn_2_98),len(tehran_df_ThreeReg_pn_3_98))
tehran_df_ThreeReg_pn_1_same_length_98 = tehran_df_ThreeReg_pn_1_98[-max_length_ThreeReg_pn_90_98:]
tehran_df_ThreeReg_pn_2_same_length_98 = tehran_df_ThreeReg_pn_2_98[-max_length_ThreeReg_pn_90_98:]
tehran_df_ThreeReg_pn_3_same_length_98 = tehran_df_ThreeReg_pn_3_98[-max_length_ThreeReg_pn_90_98:]

# %% [markdown]
# ## Tehran pn 6 Regimed DF Normed Return 90 Far - 98 Dey

# %%
tehran_df_SixReg_pn_1_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==1]
tehran_df_SixReg_pn_2_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==2]
tehran_df_SixReg_pn_3_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==3]
tehran_df_SixReg_pn_4_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==4]
tehran_df_SixReg_pn_5_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==5]
tehran_df_SixReg_pn_6_98 = tehran_df[tehran_df_reg.iloc[:-300]['3_PN']==6]

# %% [markdown]
# ## Tehran pn 6 Regimed DF Normed Return 90 Far - 98 Dey / Same Length

# %%
max_length_SixReg_pn_90_98 = min(len(tehran_df_SixReg_pn_1_98), len(tehran_df_SixReg_pn_2_98),len(tehran_df_SixReg_pn_3_98),\
                                  len(tehran_df_SixReg_pn_4_98), len(tehran_df_SixReg_pn_5_98),len(tehran_df_SixReg_pn_6_98))
tehran_df_SixReg_pn_1_same_length_98 = tehran_df_SixReg_pn_1_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_2_same_length_98 = tehran_df_SixReg_pn_2_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_3_same_length_98 = tehran_df_SixReg_pn_3_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_4_same_length_98 = tehran_df_SixReg_pn_4_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_5_same_length_98 = tehran_df_SixReg_pn_5_98[-max_length_SixReg_pn_90_98:]
tehran_df_SixReg_pn_6_same_length_98 = tehran_df_SixReg_pn_6_98[-max_length_SixReg_pn_90_98:]

# %% [markdown]
# # 1) Tehran No Regime Pearson (Based on Median Threshold) Period of 90 Far - 98 Dey

# %%
nm = Net_moduls()
thr = nm.find_median_pearson_threshold(tehran_df)
pearson_network = nm.construct_network(tehran_df, method='pearson', threshold=thr)

# %%
nm.get_network_features(pearson_network)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         4   0.514141              509            0.844978
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.514141                    0.016631
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.623547                      1.715152

# %%
a1 = dict(nx.degree(pearson_network))
a1 = np.array(dict(sorted(a1.items(), key=lambda item: item[1])))

# %%
a1
# Out:
# array({'Gold': 1, 'Euro': 2, 'USD': 2, 'GDP': 2, 'DastgahayeBargi': 2, 'FaravardehayeNafti': 3, 'M1': 3, 'HOUSE': 4, 'M2': 4, 'AbzaralatePezeshki': 5, 'HamlVaNaghl': 5, 'Coin': 6, 'Mansojat': 8, 'CPI': 20, 'CoalMining': 26, 'EntesharVaChap': 28, 'SayerMadan': 29, 'VasayelErtebati': 29, 'Shimiyaee': 29, 'Bank': 29, 'KanehayeFelezi': 29, 'Agriculture': 30, 'Wood': 30, 'paper': 30, 'FelezateAsasi': 30, 'GhandVaShekar': 30, 'Rayaneh': 30, 'FaniVaMohandesi': 30, 'EstekrajeNaft': 31, 'khodrosazi': 31, 'ChandReshteSanati': 31, 'KashiVaSeramik': 31, 'Bimeh': 31, 'MahsolateFelezi': 32, 'Lastic': 32, 'MashinAlat': 32, 'GazaeeBejozGhand': 32, 'Siman': 32, 'KanehayeGeyreFelezi': 32, 'SayerMali': 32, 'Amlakva': 32, 'Mali': 32, 'index': 33, 'Daroee': 33, 'SarmayeGozari': 33},
#       dtype=object)

# %% [markdown]
# # 2) Tehran No Regime Pearson (Based on Median Threshold) Period of 90 Far - 00 Far

# %%
thr2 = nm.find_median_pearson_threshold(tehran_df_completeDates)
pearson_network_completeDates = nm.construct_network(tehran_df_completeDates, method='pearson', threshold=thr2)

# %%
nm.get_network_features(pearson_network_completeDates)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       3         5   0.489855              507            0.800189
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.489855                    0.016996
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.611045                      1.747826

# %%
a2 = dict(nx.degree(pearson_network_completeDates))
a2 = np.array(dict(sorted(a2.items(), key=lambda item: item[1])))
a2
# Out:
# array({'Brent Oil': 1, 'Gold': 1, 'DastgahayeBargi': 2, 'AbzaralatePezeshki': 2, 'USD': 3, 'M1': 3, 'GDP': 3, 'Coin': 4, 'Euro': 4, 'M2': 4, 'FaravardehayeNafti': 7, 'Mansojat': 8, 'HOUSE': 10, 'Mali': 10, 'CPI': 12, 'HamlVaNaghl': 21, 'CoalMining': 25, 'VasayelErtebati': 27, 'Agriculture': 28, 'SayerMadan': 28, 'EntesharVaChap': 28, 'Wood': 29, 'paper': 29, 'Bank': 29, 'EstekrajeNaft': 30, 'MahsolateFelezi': 30, 'Lastic': 30, 'Bimeh': 30, 'Rayaneh': 30, 'FaniVaMohandesi': 30, 'KanehayeFelezi': 30, 'GhandVaShekar': 31, 'KashiVaSeramik': 31, 'Siman': 31, 'MashinAlat': 32, 'khodrosazi': 32, 'GazaeeBejozGhand': 32, 'Daroee': 32, 'KanehayeGeyreFelezi': 32, 'SayerMali': 32, 'ChandReshteSanati': 33, 'SarmayeGozari': 33, 'Amlakva': 33, 'index': 34, 'FelezateAsasi': 34, 'Shimiyaee': 34},
#       dtype=object)

# %% [markdown]
# # 3) Tehran No Regime Entropy (Based on Median Threshold) Period of 90 Far - 98 Dey

# %%
nm = Net_moduls()
thr3 = nm.find_median_entropy_threshold(tehran_df)
entropy_network = nm.construct_network(tehran_df, method='entropy', threshold=thr3)

# %%
nm.get_network_features(entropy_network)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.666667              690            0.742862
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.666667                    0.007576
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                   0.76105                      1.333333

# %%
a3 = dict(nx.degree(entropy_network))
a3 = np.array(dict(sorted(a3.items(), key=lambda item: item[1])))
a3
# Out:
# array({'M1': 12, 'M2': 12, 'AbzaralatePezeshki': 13, 'Brent Oil': 16, 'Gold': 16, 'CPI': 18, 'GDP': 18, 'HOUSE': 22, 'Coin': 24, 'Euro': 24, 'Rayaneh': 25, 'USD': 26, 'GhandVaShekar': 27, 'SayerMadan': 28, 'Agriculture': 28, 'KanehayeFelezi': 29, 'paper': 30, 'FaravardehayeNafti': 31, 'Shimiyaee': 31, 'SayerMali': 31, 'MahsolateFelezi': 31, 'EntesharVaChap': 32, 'FaniVaMohandesi': 33, 'Mali': 33, 'ChandReshteSanati': 34, 'Bimeh': 34, 'DastgahayeBargi': 34, 'SarmayeGozari': 34, 'KanehayeGeyreFelezi': 34, 'index': 35, 'Wood': 35, 'FelezateAsasi': 35, 'KashiVaSeramik': 35, 'Bank': 35, 'HamlVaNaghl': 35, 'Mansojat': 36, 'Lastic': 36, 'VasayelErtebati': 36, 'khodrosazi': 36, 'GazaeeBejozGhand': 36, 'Daroee': 36, 'Amlakva': 37, 'Siman': 38, 'EstekrajeNaft': 39, 'CoalMining': 40, 'MashinAlat': 40},
#       dtype=object)

# %%
circos = nm.plot_circos_network(entropy_network)
circos.draw()

# %% [markdown]
# # 4) Tehran No Regime Entropy (Based on Median Threshold) Period of 90 Far - 00 Far

# %%
thr4 = nm.find_median_entropy_threshold(tehran_df_completeDates)
entropy_network_completeDates = nm.construct_network(tehran_df_completeDates, method='entropy', threshold=thr4)

# %%
nm.get_network_features(entropy_network_completeDates)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         3   0.614493              636            0.785619
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.614493                    0.008849
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.738538                      1.389372

# %%
a4 = dict(nx.degree(entropy_network_completeDates))
a4 = np.array(dict(sorted(a4.items(), key=lambda item: item[1])))
a4
# Out:
# array({'GDP': 6, 'M1': 6, 'Gold': 6, 'M2': 10, 'USD': 11, 'AbzaralatePezeshki': 12, 'Euro': 13, 'GhandVaShekar': 13, 'HOUSE': 14, 'Brent Oil': 14, 'Coin': 15, 'CPI': 16, 'Mansojat': 23, 'EntesharVaChap': 26, 'paper': 28, 'Agriculture': 29, 'SayerMali': 29, 'Wood': 30, 'khodrosazi': 31, 'GazaeeBejozGhand': 31, 'Bank': 31, 'KanehayeFelezi': 31, 'SayerMadan': 32, 'DastgahayeBargi': 32, 'KanehayeGeyreFelezi': 32, 'SarmayeGozari': 33, 'Bimeh': 33, 'Amlakva': 33, 'Mali': 33, 'MashinAlat': 34, 'Rayaneh': 34, 'MahsolateFelezi': 35, 'Lastic': 35, 'VasayelErtebati': 35, 'FaniVaMohandesi': 35, 'FaravardehayeNafti': 36, 'Daroee': 36, 'KashiVaSeramik': 36, 'CoalMining': 37, 'EstekrajeNaft': 37, 'ChandReshteSanati': 37, 'Shimiyaee': 37, 'HamlVaNaghl': 37, 'Siman': 38, 'FelezateAsasi': 39, 'index': 41},
#       dtype=object)

# %%
circos = nm.plot_circos_network(entropy_network_completeDates)
circos.draw()

# %% [markdown]
# # 5) Tehran No Regime Crossed (Based on Median Threshold) Period of 90 Far - 98 Dey

# %%
thr5 = nm.find_median_crossed_threshold(tehran_df)
crossed_network = nm.construct_network(tehran_df, method='crossed', threshold=thr5)

# %%
nm.get_network_features(crossed_network)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         3   0.286957              297            0.445106
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.286957                    0.016645
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.585873                      1.732367

# %%
a5 = dict(nx.degree(crossed_network))
a5 = np.array(dict(sorted(a5.items(), key=lambda item: item[1])))
a5
# Out:
# array({'index': 2, 'Amlakva': 3, 'EstekrajeNaft': 3, 'FelezateAsasi': 4, 'ChandReshteSanati': 5, 'Shimiyaee': 5, 'GhandVaShekar': 6, 'KanehayeFelezi': 6, 'CoalMining': 7, 'FaniVaMohandesi': 7, 'MahsolateFelezi': 8, 'MashinAlat': 8, 'khodrosazi': 8, 'Daroee': 8, 'SayerMali': 8, 'Rayaneh': 8, 'Lastic': 8, 'Wood': 9, 'EntesharVaChap': 9, 'GazaeeBejozGhand': 9, 'Siman': 9, 'SarmayeGozari': 9, 'paper': 10, 'KashiVaSeramik': 10, 'Bank': 10, 'Agriculture': 11, 'AbzaralatePezeshki': 11, 'KanehayeGeyreFelezi': 11, 'Bimeh': 11, 'Mali': 11, 'GDP': 11, 'SayerMadan': 13, 'CPI': 13, 'VasayelErtebati': 18, 'USD': 19, 'Coin': 20, 'Gold': 20, 'Mansojat': 20, 'HamlVaNaghl': 22, 'DastgahayeBargi': 25, 'Euro': 26, 'FaravardehayeNafti': 27, 'HOUSE': 29, 'M1': 31, 'M2': 32, 'Brent Oil': 34},
#       dtype=object)

# %%
circos = nm.plot_circos_network(crossed_network)
circos.draw()

# %% [markdown]
# # 6) Tehran No Regime Crossed (Based on Median Threshold) Period of 90 Far - 00 Far

# %%
thr6 = nm.find_median_crossed_threshold(tehran_df_completeDates)
crossed_network_completeDates = nm.construct_network(tehran_df_completeDates, method='crossed_', threshold=thr6)

# %%
nm.get_network_features(crossed_network_completeDates)
# Out:
#    radius  diameter  densities  number_of_edges  average_clustering  \
# 0       2         2   0.715942              741            0.811855
#
#    avg_degree_centrality  avg_betweenness_centrality  \
# 0               0.715942                    0.006456
#
#    avg_closeness_centrality  average_shortest_path_length
# 0                  0.793385                      1.284058

# %%
a6 = dict(nx.degree(crossed_network_completeDates))
a6 = np.array(dict(sorted(a6.items(), key=lambda item: item[1])))
a6
# Out:
# array({'Brent Oil': 11, 'FaravardehayeNafti': 16, 'M2': 16, 'Gold': 17, 'M1': 17, 'Euro': 21, 'DastgahayeBargi': 21, 'Mansojat': 21, 'CPI': 22, 'Coin': 25, 'USD': 25, 'GDP': 25, 'HamlVaNaghl': 30, 'Mali': 30, 'HOUSE': 31, 'AbzaralatePezeshki': 31, 'paper': 32, 'VasayelErtebati': 33, 'CoalMining': 34, 'Agriculture': 35, 'EstekrajeNaft': 35, 'Lastic': 35, 'GazaeeBejozGhand': 35, 'KanehayeGeyreFelezi': 35, 'SayerMadan': 36, 'EntesharVaChap': 36, 'Daroee': 36, 'KashiVaSeramik': 36, 'SayerMali': 36, 'Wood': 37, 'MashinAlat': 37, 'GhandVaShekar': 37, 'Siman': 37, 'Rayaneh': 37, 'ChandReshteSanati': 38, 'Bimeh': 38, 'Bank': 39, 'KanehayeFelezi': 39, 'index': 40, 'Amlakva': 40, 'FaniVaMohandesi': 40, 'MahsolateFelezi': 41, 'Shimiyaee': 41, 'khodrosazi': 42, 'FelezateAsasi': 43, 'SarmayeGozari': 43},
#       dtype=object)
